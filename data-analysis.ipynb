# %%
import numpy as np
import pandas as pd
import sqlite3
import matplotlib.pyplot as plt

# %%
conn = sqlite3.connect('./database.sqlite')

# %%
tables = pd.read_sql("""SELECT *
                        FROM sqlite_master
                        WHERE type='table';""", conn)
tables
# Out:
#     type               name           tbl_name  rootpage  \
# 0  table    sqlite_sequence    sqlite_sequence         4
# 1  table  Player_Attributes  Player_Attributes        11
# 2  table             Player             Player        14
# 3  table              Match              Match        18
# 4  table             League             League        24
# 5  table            Country            Country        26
# 6  table               Team               Team        29
# 7  table    Team_Attributes    Team_Attributes         2
#
#                                                  sql
# 0             CREATE TABLE sqlite_sequence(name,seq)
# 1  CREATE TABLE "Player_Attributes" (\n\t`id`\tIN...
# 2  CREATE TABLE `Player` (\n\t`id`\tINTEGER PRIMA...
# 3  CREATE TABLE `Match` (\n\t`id`\tINTEGER PRIMAR...
# 4  CREATE TABLE `League` (\n\t`id`\tINTEGER PRIMA...
# 5  CREATE TABLE `Country` (\n\t`id`\tINTEGER PRIM...
# 6  CREATE TABLE "Team" (\n\t`id`\tINTEGER PRIMARY...
# 7  CREATE TABLE `Team_Attributes` (\n\t`id`\tINTE...

# %%
countries = pd.read_sql("""SELECT *
                        FROM Country;""", conn)
countries
# Out:
#        id         name
# 0       1      Belgium
# 1    1729      England
# 2    4769       France
# 3    7809      Germany
# 4   10257        Italy
# 5   13274  Netherlands
# 6   15722       Poland
# 7   17642     Portugal
# 8   19694     Scotland
# 9   21518        Spain
# 10  24558  Switzerland

# %%
leagues = pd.read_sql("""SELECT *
                        FROM League
                        JOIN Country ON Country.id = League.country_id;""", conn)
leagues
# Out:
#        id  country_id                      name     id         name
# 0       1           1    Belgium Jupiler League      1      Belgium
# 1    1729        1729    England Premier League   1729      England
# 2    4769        4769            France Ligue 1   4769       France
# 3    7809        7809     Germany 1. Bundesliga   7809      Germany
# 4   10257       10257             Italy Serie A  10257        Italy
# 5   13274       13274    Netherlands Eredivisie  13274  Netherlands
# 6   15722       15722        Poland Ekstraklasa  15722       Poland
# 7   17642       17642  Portugal Liga ZON Sagres  17642     Portugal
# 8   19694       19694   Scotland Premier League  19694     Scotland
# 9   21518       21518           Spain LIGA BBVA  21518        Spain
# 10  24558       24558  Switzerland Super League  24558  Switzerland

# %%
teams = pd.read_sql("""SELECT *
                        FROM Team
                        ORDER BY team_long_name;""", conn)
teams
# Out:
#         id  team_api_id  team_fifa_api_id            team_long_name  \
# 0    16848         8350              29.0      1. FC Kaiserslautern
# 1    15624         8722              31.0                1. FC Köln
# 2    16239         8165             171.0            1. FC Nürnberg
# 3    16243         9905             169.0           1. FSV Mainz 05
# 4    11817         8576             614.0                AC Ajaccio
# ..     ...          ...               ...                       ...
# 294  43800         9868            1742.0      Xerez Club Deportivo
# 295  31928         8021          110749.0            Zagłębie Lubin
# 296  33855         8027          112512.0         Zawisza Bydgoszcz
# 297  11822         4087          111271.0  Évian Thonon Gaillard FC
# 298  31449         8025          111092.0             Śląsk Wrocław
#
#     team_short_name
# 0               KAI
# 1               FCK
# 2               NUR
# 3               MAI
# 4               AJA
# ..              ...
# 294             XER
# 295             ZAG
# 296             ZAW
# 297             ETG
# 298             SLA
#
# [299 rows x 5 columns]

# %%
detailed_matches = pd.read_sql("""SELECT 
                                        Country.name AS country_name, 
                                        League.name AS league_name, 
                                        season, 
                                        stage, 
                                        date,
                                        HT.team_long_name AS  home_team,
                                        AT.team_long_name AS away_team,
                                        home_team_goal, 
                                        away_team_goal                                        
                                FROM Match
                                JOIN Country on Country.id = Match.country_id
                                JOIN League on League.id = Match.league_id
                                LEFT JOIN Team AS HT on HT.team_api_id = Match.home_team_api_id
                                LEFT JOIN Team AS AT on AT.team_api_id = Match.away_team_api_id
                                WHERE country_name = 'Spain'
                                ORDER by date;""", conn)
detailed_matches
# Out:
#      country_name      league_name     season  stage                 date  \
# 0           Spain  Spain LIGA BBVA  2008/2009      1  2008-08-30 00:00:00
# 1           Spain  Spain LIGA BBVA  2008/2009      1  2008-08-30 00:00:00
# 2           Spain  Spain LIGA BBVA  2008/2009      1  2008-08-31 00:00:00
# 3           Spain  Spain LIGA BBVA  2008/2009      1  2008-08-31 00:00:00
# 4           Spain  Spain LIGA BBVA  2008/2009      1  2008-08-31 00:00:00
# ...           ...              ...        ...    ...                  ...
# 3035        Spain  Spain LIGA BBVA  2015/2016     38  2016-05-15 00:00:00
# 3036        Spain  Spain LIGA BBVA  2015/2016     38  2016-05-15 00:00:00
# 3037        Spain  Spain LIGA BBVA  2015/2016     38  2016-05-15 00:00:00
# 3038        Spain  Spain LIGA BBVA  2015/2016     38  2016-05-15 00:00:00
# 3039        Spain  Spain LIGA BBVA  2015/2016     38  2016-05-15 00:00:00
#
#                       home_team        away_team  home_team_goal  \
# 0                   Valencia CF     RCD Mallorca               3
# 1                  RCD Espanyol  Real Valladolid               1
# 2                    CA Osasuna    Villarreal CF               1
# 3     RC Deportivo de La Coruña   Real Madrid CF               2
# 4                   CD Numancia     FC Barcelona               1
# ...                         ...              ...             ...
# 3035     Real Sporting de Gijón    Villarreal CF               2
# 3036        Real Betis Balompié        Getafe CF               2
# 3037               RCD Espanyol         SD Eibar               4
# 3038                  Málaga CF    UD Las Palmas               4
# 3039             Rayo Vallecano       Levante UD               3
#
#       away_team_goal
# 0                  0
# 1                  0
# 2                  1
# 3                  1
# 4                  0
# ...              ...
# 3035               0
# 3036               1
# 3037               2
# 3038               1
# 3039               1
#
# [3040 rows x 9 columns]
